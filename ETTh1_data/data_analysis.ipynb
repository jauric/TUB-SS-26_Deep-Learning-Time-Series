# %% [markdown]
# # **ETTh1 Dataset Analysis**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ETTh1_data = np.loadtxt("ETh1_data.csv", delimiter=",", skiprows = 1)  # skip header row
print(ETTh1_data.shape)
