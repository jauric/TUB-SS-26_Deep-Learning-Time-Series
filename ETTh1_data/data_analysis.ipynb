# %% [markdown]
# # **ETTh1 Dataset Analysis**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ETTh1_data = np.loadtxt("/home/johannes/Dokumente/_Arbeit/TUB Summer School/My Project Files/TUB-SS-26_Deep-Learning-Time-Series/ETTh1_data/ETTh1_data.zip", delimiter=",", skiprows = 1)  # skip header row
print(ETTh1_data.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_13850/2511527878.py in <cell line: 0>()
# ----> 1 ETTh1_data = np.loadtxt("/home/johannes/Dokumente/_Arbeit/TUB Summer School/My Project Files/TUB-SS-26_Deep-Learning-Time-Series/ETTh1_data/ETTh1_data.zip", delimiter=",", skiprows = 1)  # skip header row
#       2 print(ETTh1_data.shape)
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1379         delimiter = delimiter.decode('latin1')
#    1380
# -> 1381     arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1382                 converters=converters, skiplines=skiprows, usecols=usecols,
#    1383                 unpack=unpack, ndmin=ndmin, encoding=encoding,
#
# ...
