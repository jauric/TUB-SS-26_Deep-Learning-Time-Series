# %% [markdown]
# # **ETTh1 Dataset Analysis**
# - Using Google Colab for execution

# %%
# Check if running in Google Colab
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

# If in Google Colab, set up the environment and go 
if IN_COLAB:
    # %cd /content
    # Check if the repository is already cloned; if not, clone it
    # !test -d TUB-SS-26_Deep-Learning-Time-Series/.git || git clone https://github.com/jauric/TUB-SS-26_Deep-Learning-Time-Series.git
    # Go to ETTh1_data directory
    # %cd TUB-SS-26_Deep-Learning-Time-Series/ETTh1_data
else:
    print("Local environment detected — skipping Colab setup.")
# Out:
# /content
# /content/TUB-SS-26_Deep-Learning-Time-Series/ETTh1_data

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
ETTh1_link = "ETTh1.csv"

data_ETTh1 = pd.read_csv(ETTh1_link)
data_ETTh1.head()
# Out:
#                   date   HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# 0  2016-07-01 00:00:00  5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 1  2016-07-01 01:00:00  5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2  2016-07-01 02:00:00  5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 3  2016-07-01 03:00:00  5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 4  2016-07-01 04:00:00  5.358  1.942  1.492  0.462  3.868  1.279  21.948000

# %%
# Parse the date column to make it more readable 
dates = pd.to_datetime(data_ETTh1["date"])

figure, axes = plt.subplots(1, 2, figsize=(16, 5))

axes[0].plot(dates, data_ETTh1["HUFL"])
axes[0].set_title("HUFL")

axes[1].plot(dates, data_ETTh1["HULL"])
axes[1].set_title("HULL")

for ax in axes:
    ax.set_xlabel("date")
    # One tick per month
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
    for label in ax.get_xticklabels():
        label.set_rotation(45)
        label.set_ha("right")

plt.tight_layout()
plt.show()
